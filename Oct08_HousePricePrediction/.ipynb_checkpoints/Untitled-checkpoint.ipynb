# %% [markdown]
# # HOUSE PRICE PREDICTION

# %%
import os
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
path = os.getcwd()
path
# Out:
# '/home/sa05975666/Oct 08_HousePricePrediction'

# %%
train_df = pd.read_csv(path + '/House_Price_Prediction/train.csv')
test_df = pd.read_csv(path + '/House_Price_Prediction/test.csv')

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (1460, 81)
# (1459, 80)

# %%
target = train_df['SalePrice']

# %%
def analyze_for_miss_val(data):
    
    missing_val_col = []
    for col in data.columns:
        if data[col].isnull().sum() != 0:
            missing_val_col.append(col)
            
    
    miss_val = data[missing_val_col].isnull().sum()

#     col_tobe_removed = []
#     for row in miss_val.index:
#         if (miss_val[row]/data.shape[0] * 100) > 90:
#             col_tobe_removed.append(row)
    
    return miss_val

# %%
# create a master - all data df
train_len = train_df.shape[0]
df = train_df.append(test_df, sort = False)

miss_df = analyze_for_miss_val(df)
df = df.drop(['SalePrice', 'Id'], axis = 1)

miss_df.head()
# Out:
# MSZoning          4
# LotFrontage     486
# Alley          2721
# Utilities         2
# Exterior1st       1
# dtype: int64

# %%
objs = ['MSSubClass', 'OverallQual', 'MoSold']
for col in objs:
    df[col] = df[col].astype(object)

# %%
num_col = []
cat_col = []

for col in df.columns:
    if df[col].dtype == object:
        cat_col.append(col)
    else:
        num_col.append(col)
        
print(num_col)
print('\n', cat_col)
# Out:
# ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']
#
#  ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
df[num_col] = df[num_col].apply(lambda x:x.fillna(0))  # Filling NA of num_col with '0'
df[cat_col] = df[cat_col].apply(lambda x:x.fillna('None')) # Filling NA of cat_col with 'None' as separate category

# %%
df[num_col].describe().transpose()
# Out:
#                 count          mean          std     min     25%     50%  \
# MSSubClass     2919.0     57.137718    42.517628    20.0    20.0    50.0
# LotFrontage    2919.0     57.766701    33.481636     0.0    43.0    63.0
# LotArea        2919.0  10168.114080  7886.996359  1300.0  7478.0  9453.0
# OverallQual    2919.0      6.089072     1.409947     1.0     5.0     6.0
# OverallCond    2919.0      5.564577     1.113131     1.0     5.0     5.0
# YearBuilt      2919.0   1971.312778    30.291442  1872.0  1953.5  1973.0
# YearRemodAdd   2919.0   1984.264474    20.894344  1950.0  1965.0  1993.0
# MasVnrArea     2919.0    101.396026   178.854579     0.0     0.0     0.0
# BsmtFinSF1     2919.0    441.272011   455.606014     0.0     0.0   368.0
# BsmtFinSF2     2919.0     49.565262   169.179104     0.0     0.0     0.0
# BsmtUnfSF      2919.0    560.579993   439.590889     0.0   220.0   467.0
# TotalBsmtSF    2919.0   1051.417266   441.120498     0.0   793.0   989.0
# 1stFlrSF       2919.0   1159.581706   392.362079   334.0   876.0  1082.0
# 2ndFlrSF       2919.0    336.483727   428.701456     0.0     0.0     0.0
# LowQualFinSF   2919.0      4.694416    46.396825     0.0     0.0     0.0
# GrLivArea      2919.0   1500.759849   506.051045   334.0  1126.0  1444.0
# BsmtFullBath   2919.0      0.429599     0.524676     0.0     0.0     0.0
# BsmtHalfBath   2919.0      0.061322     0.245608     0.0     0.0     0.0
# FullBath       2919.0      1.568003     0.552969     0.0     1.0     2.0
# HalfBath       2919.0      0.380267     0.502872     0.0     0.0     0.0
# BedroomAbvGr   2919.0      2.860226     0.822693     0.0     2.0     3.0
# KitchenAbvGr   2919.0      1.044536     0.214462     0.0     1.0     1.0
# TotRmsAbvGrd   2919.0      6.451524     1.569379     2.0     5.0     6.0
# Fireplaces     2919.0      0.597122     0.646129     0.0     0.0     1.0
# GarageYrBlt    2919.0   1870.364166   449.686321     0.0  1957.0  1977.0
# GarageCars     2919.0      1.766016     0.762196     0.0     1.0     2.0
# GarageArea     2919.0    472.712573   215.535686     0.0   320.0   480.0
# WoodDeckSF     2919.0     93.709832   126.526589     0.0     0.0     0.0
# OpenPorchSF    2919.0     47.486811    67.575493     0.0     0.0    26.0
# EnclosedPorch  2919.0     23.098321    64.244246     0.0     0.0     0.0
# 3SsnPorch      2919.0      2.602261    25.188169     0.0     0.0     0.0
# ScreenPorch    2919.0     16.062350    56.184365     0.0     0.0     0.0
# PoolArea       2919.0      2.251799    35.663946     0.0     0.0     0.0
# MiscVal        2919.0     50.825968   567.402211     0.0     0.0     0.0
# MoSold         2919.0      6.213087     2.714762     1.0     4.0     6.0
# YrSold         2919.0   2007.792737     1.314964  2006.0  2007.0  2008.0
#
#                    75%       max
# MSSubClass        70.0     190.0
# LotFrontage       78.0     313.0
# LotArea        11570.0  215245.0
# OverallQual        7.0      10.0
# OverallCond        6.0       9.0
# YearBuilt       2001.0    2010.0
# YearRemodAdd    2004.0    2010.0
# MasVnrArea       163.5    1600.0
# BsmtFinSF1       733.0    5644.0
# BsmtFinSF2         0.0    1526.0
# BsmtUnfSF        805.0    2336.0
# TotalBsmtSF     1302.0    6110.0
# 1stFlrSF        1387.5    5095.0
# 2ndFlrSF         704.0    2065.0
# LowQualFinSF       0.0    1064.0
# GrLivArea       1743.5    5642.0
# BsmtFullBath       1.0       3.0
# BsmtHalfBath       0.0       2.0
# FullBath           2.0       4.0
# HalfBath           1.0       2.0
# BedroomAbvGr       3.0       8.0
# KitchenAbvGr       1.0       3.0
# TotRmsAbvGrd       7.0      15.0
# Fireplaces         1.0       4.0
# GarageYrBlt     2001.0    2207.0
# GarageCars         2.0       5.0
# GarageArea       576.0    1488.0
# WoodDeckSF       168.0    1424.0
# OpenPorchSF       70.0     742.0
# EnclosedPorch      0.0    1012.0
# 3SsnPorch          0.0     508.0
# ScreenPorch        0.0     576.0
# PoolArea           0.0     800.0
# MiscVal            0.0   17000.0
# MoSold             8.0      12.0
# YrSold          2009.0    2010.0

# %%
df.hist(figsize = (20,20))
plt.tight_layout()

# %%
df[cat_col].apply(lambda x:(len(x.unique()), [x.unique()]))
# Out:
# MSSubClass       (16, [[60, 20, 70, 50, 190, 45, 90, 120, 30, 8...
# MSZoning                    (6, [[RL, RM, C (all), FV, RH, None]])
# Street                                         (2, [[Pave, Grvl]])
# LotShape                               (4, [[Reg, IR1, IR2, IR3]])
# LandContour                            (4, [[Lvl, Bnk, Low, HLS]])
# Utilities                            (3, [[AllPub, NoSeWa, None]])
# LotConfig               (5, [[Inside, FR2, Corner, CulDSac, FR3]])
# LandSlope                                   (3, [[Gtl, Mod, Sev]])
# Neighborhood     (25, [[CollgCr, Veenker, Crawfor, NoRidge, Mit...
# Condition1       (9, [[Norm, Feedr, PosN, Artery, RRAe, RRNn, R...
# Condition2       (8, [[Norm, Artery, RRNn, Feedr, PosN, PosA, R...
# BldgType              (5, [[1Fam, 2fmCon, Duplex, TwnhsE, Twnhs]])
# HouseStyle       (8, [[2Story, 1Story, 1.5Fin, 1.5Unf, SFoyer, ...
# OverallQual                (10, [[7, 6, 8, 5, 9, 4, 10, 3, 1, 2]])
# RoofStyle        (6, [[Gable, Hip, Gambrel, Mansard, Flat, Shed]])
# RoofMatl         (8, [[CompShg, WdShngl, Metal, WdShake, Membra...
# Exterior1st      (16, [[VinylSd, MetalSd, Wd Sdng, HdBoard, Brk...
# Exterior2nd      (17, [[VinylSd, MetalSd, Wd Shng, HdBoard, Ply...
# MasVnrType                   (4, [[BrkFace, None, Stone, BrkCmn]])
# ExterQual                                  (4, [[Gd, TA, Ex, Fa]])
# ExterCond                              (5, [[TA, Gd, Fa, Po, Ex]])
# Foundation       (6, [[PConc, CBlock, BrkTil, Wood, Slab, Stone]])
# BsmtQual                             (5, [[Gd, TA, Ex, None, Fa]])
# BsmtCond                             (5, [[TA, Gd, None, Fa, Po]])
# BsmtExposure                         (5, [[No, Gd, Mn, Av, None]])
# BsmtFinType1           (7, [[GLQ, ALQ, Unf, Rec, BLQ, None, LwQ]])
# BsmtFinType2           (7, [[Unf, BLQ, None, ALQ, Rec, LwQ, GLQ]])
# Heating               (6, [[GasA, GasW, Grav, Wall, OthW, Floor]])
# HeatingQC                              (5, [[Ex, Gd, TA, Fa, Po]])
# CentralAir                                           (2, [[Y, N]])
# Electrical          (6, [[SBrkr, FuseF, FuseA, FuseP, Mix, None]])
# KitchenQual                          (5, [[Gd, TA, Ex, Fa, None]])
# Functional       (8, [[Typ, Min1, Maj1, Min2, Mod, Maj2, Sev, N...
# FireplaceQu                      (6, [[None, TA, Gd, Fa, Ex, Po]])
# GarageType       (7, [[Attchd, Detchd, BuiltIn, CarPort, None, ...
# GarageFinish                          (4, [[RFn, Unf, Fin, None]])
# GarageQual                       (6, [[TA, Fa, Gd, None, Ex, Po]])
# GarageCond                       (6, [[TA, Fa, None, Gd, Po, Ex]])
# PavedDrive                                        (3, [[Y, N, P]])
# Fence                      (5, [[None, MnPrv, GdWo, GdPrv, MnWw]])
# SaleType         (10, [[WD, New, COD, ConLD, ConLI, CWD, ConLw,...
# SaleCondition    (6, [[Normal, Abnorml, Partial, AdjLand, Alloc...
# dtype: object

# %%
plt.plot(train_df['LotArea'], target, 'o')
plt.xlabel('LotArea')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.plot(train_df['OverallQual'], target, 'o')
plt.xlabel('OverallQual')
plt.ylabel('SalePrice')
plt.show()

# %%
train_df.groupby(col).agg('SalePrice').plot.bar()

# %%
plt.figure(figsize = (25,25))
sns.heatmap(df.corr(),annot = False)

# %%
lab_col = ['ExterQual', 'ExterCond','BsmtQual','BsmtCond', 'BsmtExposure', 'BsmtFinType1', 
           'BsmtFinType2', 'HeatingQC', 'KitchenQual', 'FireplaceQu', 'GarageQual', 'GarageCond', 'Fence']

from sklearn import preprocessing
for col in lab_col:
    le = preprocessing.LabelEncoder()
    df[col] = le.fit_transform(df[col])
    
df[lab_col].apply(lambda x:(len(x.unique()), [x.unique()]))

# %%
predictors = pd.get_dummies(df, drop_first =  True)
predictors.shape
# Out:
# (2919, 213)

# %%
train_data = predictors[:train_len]
test_data = predictors[train_len:]

# %%
sns.distplot(target)

# %%
train_labels = np.log(target)
sns.distplot(train_labels)

# %%
#importing packages from sk learn

from sklearn.model_selection import train_test_split


#FUNCTION for Train & Validation set
X_train, X_test, y_train, y_test = train_test_split(train_data, train_labels, 
                                                    test_size=0.2, random_state = 123)

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, r2_score


def get_score(predicted, original):    
    r2 = r2_score(predicted, original)
    rmse = np.sqrt(mean_squared_error(predicted, original)) 
    return r2, rmse


def build_model(model, x_trn, x_tst, y_trn, y_tst):
    
    model = model.fit(x_trn, y_trn)
    
    #train-prediction & results
    y_trn_pred = model.predict(x_trn)
    trn_r2, trn_rmse = get_score(y_trn_pred, y_trn)
    
    # results on validation set
    y_pred = model.predict(x_tst)
    test_r2, test_rmse = get_score(y_pred, y_tst)
    
    return trn_r2, trn_rmse, test_r2, test_rmse

def feature_imp(model):
    features = predictors.columns
    importances = model.feature_importances_
    indices = np.argsort(importances[:10])
    
    fImp_Asc = []
    
    for i in indices:
        n = features[i]
        fImp_Asc.append(n)
        
    plt.figure(figsize=(5,5))
    plt.barh(range(len(indices)), importances[indices], color='b', align='center')
    plt.yticks(range(len(indices)), [features[i] for i in indices])
    plt.xlabel('Relative Importance')
    plt.title('Feature Importances')
    plt.show()
    

def model_with_kfold(model, X, y, folds):
    
    print('Model Summary: \n{}' .format(model))
    
    print('\n Data Folds: {}'.format(folds))
    
    train_R2 = []
    train_RMSE = []
    test_R2 = []
    test_RMSE = []
    
    kf = KFold(n_splits = folds, random_state = 123) 
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        trn_r2, trn_rmse, test_r2, test_rmse = build_model(model, X_train, X_test, y_train, y_test)
        
        train_R2.append(trn_r2)
        train_RMSE.append(trn_rmse)
        test_R2.append(test_r2)
        test_RMSE.append(test_rmse)

    print('\n TRAINING:')   
    print('KFold R2: {}' .format(np.array(train_R2).mean()))
    print('KFold RMSE: {}' .format(np.array(train_RMSE).mean()))
    
    print('\n VALIDATION: ')
    print('KFold R2: {}' .format(np.array(test_R2).mean()))
    print('KFold RMSE: {}' .format(np.array(test_RMSE).mean()))
    
    feature_imp(model)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler

rc = RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True, with_scaling=True)
X = rc.fit_transform(train_data)

#X = np.array(train_data)

y = np.array(train_labels)

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR

# %%
lr = linearRegressor(n_estimators = 1000, n_jobs =-1)
model_with_kfold(lr, X, y, 5)

# %%
ridge = linearRegressor(n_estimators = 1000, n_jobs =-1)
model_with_kfold(ridge, X, y, 5)

# %%
lasso = linearRegressor(n_estimators = 1000, n_jobs =-1)
model_with_kfold(lasso, X, y, 5)

# %%
en = linearRegressor(n_estimators = 1000, n_jobs =-1)
model_with_kfold(en, X, y, 5)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor

rfr = RandomForestRegressor(n_estimators = 1000, n_jobs =-1)
model_with_kfold(rfr, X, y, 5)
# Out:
# Model Summary:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)
#
#  Data Folds: 5
#
#  TRAINING:
# KFold R2: 0.979954078137038
# KFold RMSE: 0.05341158246347494
#
#  VALIDATION:
# KFold R2: 0.8359646363911694
# KFold RMSE: 0.14356342577979422

# %%
adr = AdaBoostRegressor(n_estimators = 1000)
model_with_kfold(adr, X, y, 5)
# Out:
# Model Summary:
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#          n_estimators=1000, random_state=None)
#
#  Data Folds: 5
#
#  TRAINING:
# KFold R2: 0.8528885483545766
# KFold RMSE: 0.1485172365145828
#
#  VALIDATION:
# KFold R2: 0.7896193243716608
# KFold RMSE: 0.17443815092875944

# %%
gbr = GradientBoostingRegressor(n_estimators = 1000)
model_with_kfold(gbr, X, y, 5)
# Out:
# Model Summary:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=1000, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)
#
#  Data Folds: 5
#
#  TRAINING:
# KFold R2: 0.998242436903533
# KFold RMSE: 0.016644667643101414
#
#  VALIDATION:
# KFold R2: 0.8860906602528204
# KFold RMSE: 0.12792635837849398

# %%
import xgboost as xgb
xgr = xgb.XGBRegressor(n_estimators = 1000, n_jobs = -1)
model_with_kfold(xgr, X, y, 5)
# Out:
# Model Summary:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
#        n_jobs=-1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)
#
#  Data Folds: 5
#
#  TRAINING:
# KFold R2: 0.9973438307127008
# KFold RMSE: 0.020422598535580844
#
#  VALIDATION:
# KFold R2: 0.8820459061192697
# KFold RMSE: 0.12957675516945752

# %%
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
import xgboost as xgb


predicted = cross_val_predict(estimator, train_data, train_labels, cv = 10)
sqrt(mean_squared_error(train_labels, predicted)) #RMSE
# Out:
# 0.12657588423198496
